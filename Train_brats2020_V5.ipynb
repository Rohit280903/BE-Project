# %%
import os
import numpy as np
from custom_datagen import imageLoader
# from datagen import imageLoader 
# from keras.preprocessing.image import ImageDataGenerator
#import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random

# %%
import os
import numpy as np


def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)

def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            yield (X,Y) #a tuple with two numpy arrays with batch_size samples     

            batch_start += batch_size   
            batch_end += batch_size

# %%
train_img_dir = "BraTS2020_TrainingData/input_data_128/train/images/"
train_mask_dir = "BraTS2020_TrainingData/input_data_128/train/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('BraTS2020_TrainingData/input_data_128/train/masks/*.npy'))
for img in range(len(train_mask_list)):
    print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4

wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 6
# 7
# 8
# 9
# 10
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 11
# 12
# 13
# 14
# 15
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 16
# 17
# 18
# 19
# 20
# 21
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 22
# 23
# 24
# 25
# 26
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 27
# 28
# 29
# 30
# 31
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 32
# 33
# 34
# 35
# 36
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 37
# 38
# 39
# 40
# 41
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 42
# 43
# 44
# 45
# 46
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 47
# 48
# 49
# 50
# 51
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 52
# 53
# 54
# 55
# 56
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 57
# 58
# 59
# 60
# 61
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 62
# 63
# 64
# 65
# 66
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# /tmp/ipykernel_7265/1913153290.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)

# %%
train_img_dir = "BraTS2020_TrainingData/input_data_128/train/images/"
train_mask_dir = "BraTS2020_TrainingData/input_data_128/train/masks/"

val_img_dir = "BraTS2020_TrainingData/input_data_128/val/images/"
val_mask_dir = "BraTS2020_TrainingData/input_data_128/val/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
import os
os.environ['SM_FRAMEWORK'] = 'keras'

#Define loss, metrics and optimizer to be used for training
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)
# Out:
# 2024-10-22 18:22:35.090984: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.096042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.096385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.100204: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.100532: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.100820: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.180089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.180436: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.180737: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 18:22:35.181005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22493 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:81:00.0, compute capability: 8.6

# %%
#Define loss, metrics and optimizer to be used for training
import numpy as np
import tensorflow as tf 

wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)


#Fit the model 

steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size


from  simple_3d_unet import simple_unet_model


model = simple_unet_model(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=3, 
                          num_classes=4)

model.compile(optimizer = optim, loss=total_loss, metrics=metrics)
# print(model.summary())

# print(model.input_shape)
# print(model.output_shape)





history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=100,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )

model.save('brats_3d.hdf5')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 128, 3)]   0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 128, 16)    1312      ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 128, 128, 128, 16)    0         ['conv3d[0][0]']
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 128, 16)    6928      ['dropout[0][0]']
#
#  max_pooling3d (MaxPooling3  (None, 64, 64, 64, 16)       0         ['conv3d_1[0][0]']
#  D)
#
#  conv3d_2 (Conv3D)           (None, 64, 64, 64, 32)       13856     ['max_pooling3d[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 64, 32)       0         ['conv3d_2[0][0]']
#
#  conv3d_3 (Conv3D)           (None, 64, 64, 64, 32)       27680     ['dropout_1[0][0]']
#
#  max_pooling3d_1 (MaxPoolin  (None, 32, 32, 32, 32)       0         ['conv3d_3[0][0]']
#  g3D)
#
#  conv3d_4 (Conv3D)           (None, 32, 32, 32, 64)       55360     ['max_pooling3d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 32, 32, 32, 64)       0         ['conv3d_4[0][0]']
#
#  conv3d_5 (Conv3D)           (None, 32, 32, 32, 64)       110656    ['dropout_2[0][0]']
#
#  max_pooling3d_2 (MaxPoolin  (None, 16, 16, 16, 64)       0         ['conv3d_5[0][0]']
#  g3D)
#
#  conv3d_6 (Conv3D)           (None, 16, 16, 16, 128)      221312    ['max_pooling3d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 16, 16, 16, 128)      0         ['conv3d_6[0][0]']
#
#  conv3d_7 (Conv3D)           (None, 16, 16, 16, 128)      442496    ['dropout_3[0][0]']
#
#  max_pooling3d_3 (MaxPoolin  (None, 8, 8, 8, 128)         0         ['conv3d_7[0][0]']
#  g3D)
#
#  conv3d_8 (Conv3D)           (None, 8, 8, 8, 256)         884992    ['max_pooling3d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 8, 8, 8, 256)         0         ['conv3d_8[0][0]']
#
#  conv3d_9 (Conv3D)           (None, 8, 8, 8, 256)         1769728   ['dropout_4[0][0]']
#
#  conv3d_transpose (Conv3DTr  (None, 16, 16, 16, 128)      262272    ['conv3d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 16, 256)      0         ['conv3d_transpose[0][0]',
#                                                                      'conv3d_7[0][0]']
#
#  conv3d_10 (Conv3D)          (None, 16, 16, 16, 128)      884864    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 16, 16, 16, 128)      0         ['conv3d_10[0][0]']
#
#  conv3d_11 (Conv3D)          (None, 16, 16, 16, 128)      442496    ['dropout_5[0][0]']
#
#  conv3d_transpose_1 (Conv3D  (None, 32, 32, 32, 64)       65600     ['conv3d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 32, 128)      0         ['conv3d_transpose_1[0][0]',
#  )                                                                   'conv3d_5[0][0]']
#
#  conv3d_12 (Conv3D)          (None, 32, 32, 32, 64)       221248    ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 32, 32, 32, 64)       0         ['conv3d_12[0][0]']
#
#  conv3d_13 (Conv3D)          (None, 32, 32, 32, 64)       110656    ['dropout_6[0][0]']
#
#  conv3d_transpose_2 (Conv3D  (None, 64, 64, 64, 32)       16416     ['conv3d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 64, 64)       0         ['conv3d_transpose_2[0][0]',
#  )                                                                   'conv3d_3[0][0]']
#
#  conv3d_14 (Conv3D)          (None, 64, 64, 64, 32)       55328     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 64, 64, 64, 32)       0         ['conv3d_14[0][0]']
#
#  conv3d_15 (Conv3D)          (None, 64, 64, 64, 32)       27680     ['dropout_7[0][0]']
#
#  conv3d_transpose_3 (Conv3D  (None, 128, 128, 128, 16)    4112      ['conv3d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 128, 32)    0         ['conv3d_transpose_3[0][0]',
#  )                                                                   'conv3d_1[0][0]']
#
#  conv3d_16 (Conv3D)          (None, 128, 128, 128, 16)    13840     ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 128, 128, 128, 16)    0         ['conv3d_16[0][0]']
#
#  conv3d_17 (Conv3D)          (None, 128, 128, 128, 16)    6928      ['dropout_8[0][0]']
#
#  conv3d_18 (Conv3D)          (None, 128, 128, 128, 4)     68        ['conv3d_17[0][0]']
#
# ==================================================================================================
# Total params: 5645828 (21.54 MB)
# Trainable params: 5645828 (21.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/100
# 2024-10-22 18:27:14.125759: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8700
# 2024-10-22 18:27:19.272311: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7b917a22fe40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-22 18:27:19.272355: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A5000, Compute Capability 8.6
# 2024-10-22 18:27:19.276715: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-22 18:27:19.381479: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 33/33 [==============================] - 41s 712ms/step - loss: 0.9755 - accuracy: 0.7997 - iou_score: 0.1498 - val_loss: 0.9665 - val_accuracy: 0.9586 - val_iou_score: 0.1485
# Epoch 2/100
# 33/33 [==============================] - 9s 279ms/step - loss: 0.9453 - accuracy: 0.9585 - iou_score: 0.2305 - val_loss: 0.9420 - val_accuracy: 0.9595 - val_iou_score: 0.2180
# Epoch 3/100
# 33/33 [==============================] - 9s 279ms/step - loss: 0.9348 - accuracy: 0.9621 - iou_score: 0.2371 - val_loss: 0.9355 - val_accuracy: 0.9601 - val_iou_score: 0.2193
# Epoch 4/100
# 33/33 [==============================] - 9s 277ms/step - loss: 0.9287 - accuracy: 0.9628 - iou_score: 0.2378 - val_loss: 0.9259 - val_accuracy: 0.9610 - val_iou_score: 0.2355
# Epoch 5/100
# 33/33 [==============================] - 9s 277ms/step - loss: 0.9244 - accuracy: 0.9632 - iou_score: 0.2384 - val_loss: 0.9251 - val_accuracy: 0.9598 - val_iou_score: 0.2343
# Epoch 6/100
# 33/33 [==============================] - 9s 278ms/step - loss: 0.9188 - accuracy: 0.9675 - iou_score: 0.2421 - val_loss: 0.9190 - val_accuracy: 0.9597 - val_iou_score: 0.2381
# Epoch 7/100
# 33/33 [==============================] - 9s 277ms/step - loss: 0.9131 - accuracy: 0.9696 - iou_score: 0.2615 - val_loss: 0.9156 - val_accuracy: 0.9514 - val_iou_score: 0.2936
# Epoch 8/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.9085 - accuracy: 0.9681 - iou_score: 0.3291 - val_loss: 0.9122 - val_accuracy: 0.9497 - val_iou_score: 0.3177
# Epoch 9/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.9040 - accuracy: 0.9690 - iou_score: 0.3393 - val_loss: 0.9073 - val_accuracy: 0.9558 - val_iou_score: 0.3224
# Epoch 10/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8999 - accuracy: 0.9706 - iou_score: 0.3393 - val_loss: 0.8992 - val_accuracy: 0.9614 - val_iou_score: 0.3390
# Epoch 11/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8933 - accuracy: 0.9701 - iou_score: 0.3890 - val_loss: 0.9092 - val_accuracy: 0.9296 - val_iou_score: 0.3682
# Epoch 12/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8846 - accuracy: 0.9714 - iou_score: 0.4266 - val_loss: 0.9006 - val_accuracy: 0.9372 - val_iou_score: 0.3836
# Epoch 13/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8792 - accuracy: 0.9704 - iou_score: 0.4389 - val_loss: 0.8942 - val_accuracy: 0.9424 - val_iou_score: 0.4010
# Epoch 14/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8765 - accuracy: 0.9697 - iou_score: 0.4473 - val_loss: 0.8838 - val_accuracy: 0.9580 - val_iou_score: 0.4249
# Epoch 15/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8691 - accuracy: 0.9720 - iou_score: 0.4691 - val_loss: 0.8919 - val_accuracy: 0.9461 - val_iou_score: 0.4078
# Epoch 16/100
# 33/33 [==============================] - 9s 279ms/step - loss: 0.8682 - accuracy: 0.9727 - iou_score: 0.4722 - val_loss: 0.9010 - val_accuracy: 0.9249 - val_iou_score: 0.3803
# Epoch 17/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8620 - accuracy: 0.9736 - iou_score: 0.4881 - val_loss: 0.8987 - val_accuracy: 0.9238 - val_iou_score: 0.3849
# Epoch 18/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8752 - accuracy: 0.9713 - iou_score: 0.4529 - val_loss: 0.9096 - val_accuracy: 0.9092 - val_iou_score: 0.3596
# Epoch 19/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8693 - accuracy: 0.9703 - iou_score: 0.4683 - val_loss: 0.8703 - val_accuracy: 0.9678 - val_iou_score: 0.4642
# Epoch 20/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8655 - accuracy: 0.9739 - iou_score: 0.4811 - val_loss: 0.8652 - val_accuracy: 0.9693 - val_iou_score: 0.4774
# Epoch 21/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8576 - accuracy: 0.9761 - iou_score: 0.5026 - val_loss: 0.8710 - val_accuracy: 0.9624 - val_iou_score: 0.4595
# Epoch 22/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8504 - accuracy: 0.9783 - iou_score: 0.5249 - val_loss: 0.8603 - val_accuracy: 0.9697 - val_iou_score: 0.4967
# Epoch 23/100
# 33/33 [==============================] - 9s 279ms/step - loss: 0.8455 - accuracy: 0.9784 - iou_score: 0.5415 - val_loss: 0.8527 - val_accuracy: 0.9740 - val_iou_score: 0.5200
# Epoch 24/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8419 - accuracy: 0.9784 - iou_score: 0.5541 - val_loss: 0.8510 - val_accuracy: 0.9770 - val_iou_score: 0.5245
# Epoch 25/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8406 - accuracy: 0.9790 - iou_score: 0.5582 - val_loss: 0.8496 - val_accuracy: 0.9772 - val_iou_score: 0.5284
# Epoch 26/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8436 - accuracy: 0.9780 - iou_score: 0.5486 - val_loss: 0.8604 - val_accuracy: 0.9685 - val_iou_score: 0.5008
# Epoch 27/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8409 - accuracy: 0.9788 - iou_score: 0.5564 - val_loss: 0.8564 - val_accuracy: 0.9700 - val_iou_score: 0.5118
# Epoch 28/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8380 - accuracy: 0.9794 - iou_score: 0.5681 - val_loss: 0.8509 - val_accuracy: 0.9742 - val_iou_score: 0.5249
# Epoch 29/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8328 - accuracy: 0.9808 - iou_score: 0.5863 - val_loss: 0.8562 - val_accuracy: 0.9713 - val_iou_score: 0.5099
# Epoch 30/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8318 - accuracy: 0.9797 - iou_score: 0.5908 - val_loss: 0.8539 - val_accuracy: 0.9707 - val_iou_score: 0.5205
# Epoch 31/100
# 33/33 [==============================] - 9s 278ms/step - loss: 0.8291 - accuracy: 0.9814 - iou_score: 0.5994 - val_loss: 0.8522 - val_accuracy: 0.9750 - val_iou_score: 0.5236
# Epoch 32/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8281 - accuracy: 0.9806 - iou_score: 0.6043 - val_loss: 0.8549 - val_accuracy: 0.9686 - val_iou_score: 0.5178
# Epoch 33/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8271 - accuracy: 0.9814 - iou_score: 0.6075 - val_loss: 0.8559 - val_accuracy: 0.9675 - val_iou_score: 0.5155
# Epoch 34/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8246 - accuracy: 0.9820 - iou_score: 0.6153 - val_loss: 0.8542 - val_accuracy: 0.9691 - val_iou_score: 0.5183
# Epoch 35/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8226 - accuracy: 0.9819 - iou_score: 0.6247 - val_loss: 0.8493 - val_accuracy: 0.9738 - val_iou_score: 0.5363
# Epoch 36/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8218 - accuracy: 0.9821 - iou_score: 0.6270 - val_loss: 0.8513 - val_accuracy: 0.9722 - val_iou_score: 0.5324
# Epoch 37/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8199 - accuracy: 0.9828 - iou_score: 0.6337 - val_loss: 0.8450 - val_accuracy: 0.9764 - val_iou_score: 0.5499
# Epoch 38/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8186 - accuracy: 0.9832 - iou_score: 0.6394 - val_loss: 0.8489 - val_accuracy: 0.9727 - val_iou_score: 0.5389
# Epoch 39/100
# 33/33 [==============================] - 9s 288ms/step - loss: 0.8172 - accuracy: 0.9835 - iou_score: 0.6449 - val_loss: 0.8572 - val_accuracy: 0.9708 - val_iou_score: 0.5152
# Epoch 40/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8163 - accuracy: 0.9837 - iou_score: 0.6485 - val_loss: 0.8440 - val_accuracy: 0.9761 - val_iou_score: 0.5542
# Epoch 41/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8166 - accuracy: 0.9834 - iou_score: 0.6476 - val_loss: 0.8434 - val_accuracy: 0.9759 - val_iou_score: 0.5545
# Epoch 42/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8166 - accuracy: 0.9826 - iou_score: 0.6480 - val_loss: 0.8454 - val_accuracy: 0.9768 - val_iou_score: 0.5494
# Epoch 43/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8178 - accuracy: 0.9824 - iou_score: 0.6437 - val_loss: 0.8496 - val_accuracy: 0.9768 - val_iou_score: 0.5321
# Epoch 44/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8145 - accuracy: 0.9840 - iou_score: 0.6566 - val_loss: 0.8504 - val_accuracy: 0.9731 - val_iou_score: 0.5313
# Epoch 45/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8112 - accuracy: 0.9844 - iou_score: 0.6703 - val_loss: 0.8599 - val_accuracy: 0.9626 - val_iou_score: 0.5078
# Epoch 46/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8120 - accuracy: 0.9842 - iou_score: 0.6677 - val_loss: 0.8346 - val_accuracy: 0.9774 - val_iou_score: 0.5826
# Epoch 47/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8137 - accuracy: 0.9831 - iou_score: 0.6605 - val_loss: 0.8453 - val_accuracy: 0.9720 - val_iou_score: 0.5514
# Epoch 48/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8095 - accuracy: 0.9850 - iou_score: 0.6766 - val_loss: 0.8361 - val_accuracy: 0.9755 - val_iou_score: 0.5788
# Epoch 49/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8080 - accuracy: 0.9854 - iou_score: 0.6817 - val_loss: 0.8354 - val_accuracy: 0.9727 - val_iou_score: 0.5860
# Epoch 50/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8073 - accuracy: 0.9856 - iou_score: 0.6853 - val_loss: 0.8351 - val_accuracy: 0.9761 - val_iou_score: 0.5856
# Epoch 51/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8061 - accuracy: 0.9859 - iou_score: 0.6907 - val_loss: 0.8303 - val_accuracy: 0.9792 - val_iou_score: 0.6012
# Epoch 52/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8061 - accuracy: 0.9857 - iou_score: 0.6905 - val_loss: 0.8313 - val_accuracy: 0.9792 - val_iou_score: 0.5975
# Epoch 53/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8109 - accuracy: 0.9847 - iou_score: 0.6699 - val_loss: 0.8323 - val_accuracy: 0.9779 - val_iou_score: 0.5970
# Epoch 54/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8096 - accuracy: 0.9845 - iou_score: 0.6761 - val_loss: 0.8321 - val_accuracy: 0.9782 - val_iou_score: 0.5991
# Epoch 55/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8057 - accuracy: 0.9861 - iou_score: 0.6921 - val_loss: 0.8280 - val_accuracy: 0.9810 - val_iou_score: 0.6043
# Epoch 56/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8059 - accuracy: 0.9857 - iou_score: 0.6910 - val_loss: 0.8287 - val_accuracy: 0.9802 - val_iou_score: 0.6035
# Epoch 57/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8054 - accuracy: 0.9860 - iou_score: 0.6935 - val_loss: 0.8287 - val_accuracy: 0.9801 - val_iou_score: 0.6069
# Epoch 58/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.8038 - accuracy: 0.9858 - iou_score: 0.7011 - val_loss: 0.8270 - val_accuracy: 0.9817 - val_iou_score: 0.6111
# Epoch 59/100
# 33/33 [==============================] - 9s 285ms/step - loss: 0.8029 - accuracy: 0.9863 - iou_score: 0.7033 - val_loss: 0.8275 - val_accuracy: 0.9815 - val_iou_score: 0.6088
# Epoch 60/100
# 33/33 [==============================] - 9s 285ms/step - loss: 0.8091 - accuracy: 0.9841 - iou_score: 0.6790 - val_loss: 0.8283 - val_accuracy: 0.9810 - val_iou_score: 0.6078
# Epoch 61/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8068 - accuracy: 0.9857 - iou_score: 0.6876 - val_loss: 0.8350 - val_accuracy: 0.9748 - val_iou_score: 0.5847
# Epoch 62/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.8048 - accuracy: 0.9859 - iou_score: 0.6961 - val_loss: 0.8340 - val_accuracy: 0.9758 - val_iou_score: 0.5890
# Epoch 63/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8022 - accuracy: 0.9864 - iou_score: 0.7076 - val_loss: 0.8400 - val_accuracy: 0.9678 - val_iou_score: 0.5698
# Epoch 64/100
# 33/33 [==============================] - 9s 285ms/step - loss: 0.8018 - accuracy: 0.9865 - iou_score: 0.7094 - val_loss: 0.8354 - val_accuracy: 0.9782 - val_iou_score: 0.5849
# Epoch 65/100
# 33/33 [==============================] - 9s 285ms/step - loss: 0.8023 - accuracy: 0.9865 - iou_score: 0.7072 - val_loss: 0.8402 - val_accuracy: 0.9748 - val_iou_score: 0.5715
# Epoch 66/100
# 33/33 [==============================] - 9s 286ms/step - loss: 0.8002 - accuracy: 0.9873 - iou_score: 0.7171 - val_loss: 0.8374 - val_accuracy: 0.9774 - val_iou_score: 0.5797
# Epoch 67/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7994 - accuracy: 0.9876 - iou_score: 0.7198 - val_loss: 0.8372 - val_accuracy: 0.9804 - val_iou_score: 0.5795
# Epoch 68/100
# 33/33 [==============================] - 9s 281ms/step - loss: 0.8007 - accuracy: 0.9869 - iou_score: 0.7133 - val_loss: 0.8396 - val_accuracy: 0.9802 - val_iou_score: 0.5710
# Epoch 69/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.8000 - accuracy: 0.9869 - iou_score: 0.7179 - val_loss: 0.8251 - val_accuracy: 0.9823 - val_iou_score: 0.6200
# Epoch 70/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.8008 - accuracy: 0.9867 - iou_score: 0.7128 - val_loss: 0.8369 - val_accuracy: 0.9805 - val_iou_score: 0.5802
# Epoch 71/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7986 - accuracy: 0.9877 - iou_score: 0.7228 - val_loss: 0.8279 - val_accuracy: 0.9813 - val_iou_score: 0.6095
# Epoch 72/100
# 33/33 [==============================] - 9s 279ms/step - loss: 0.8005 - accuracy: 0.9864 - iou_score: 0.7154 - val_loss: 0.8321 - val_accuracy: 0.9792 - val_iou_score: 0.5971
# Epoch 73/100
# 33/33 [==============================] - 9s 288ms/step - loss: 0.7979 - accuracy: 0.9876 - iou_score: 0.7265 - val_loss: 0.8357 - val_accuracy: 0.9739 - val_iou_score: 0.5862
# Epoch 74/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7975 - accuracy: 0.9880 - iou_score: 0.7287 - val_loss: 0.8300 - val_accuracy: 0.9778 - val_iou_score: 0.6032
# Epoch 75/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7974 - accuracy: 0.9885 - iou_score: 0.7285 - val_loss: 0.8310 - val_accuracy: 0.9796 - val_iou_score: 0.6001
# Epoch 76/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7963 - accuracy: 0.9888 - iou_score: 0.7334 - val_loss: 0.8390 - val_accuracy: 0.9802 - val_iou_score: 0.5745
# Epoch 77/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7970 - accuracy: 0.9889 - iou_score: 0.7300 - val_loss: 0.8278 - val_accuracy: 0.9816 - val_iou_score: 0.6072
# Epoch 78/100
# 33/33 [==============================] - 9s 286ms/step - loss: 0.7979 - accuracy: 0.9887 - iou_score: 0.7247 - val_loss: 0.8262 - val_accuracy: 0.9813 - val_iou_score: 0.6149
# Epoch 79/100
# 33/33 [==============================] - 9s 287ms/step - loss: 0.7939 - accuracy: 0.9891 - iou_score: 0.7451 - val_loss: 0.8250 - val_accuracy: 0.9808 - val_iou_score: 0.6195
# Epoch 80/100
# 33/33 [==============================] - 9s 287ms/step - loss: 0.7926 - accuracy: 0.9897 - iou_score: 0.7513 - val_loss: 0.8272 - val_accuracy: 0.9788 - val_iou_score: 0.6125
# Epoch 81/100
# 33/33 [==============================] - 9s 287ms/step - loss: 0.7923 - accuracy: 0.9898 - iou_score: 0.7525 - val_loss: 0.8248 - val_accuracy: 0.9800 - val_iou_score: 0.6184
# Epoch 82/100
# 33/33 [==============================] - 9s 285ms/step - loss: 0.7915 - accuracy: 0.9901 - iou_score: 0.7563 - val_loss: 0.8285 - val_accuracy: 0.9776 - val_iou_score: 0.6073
# Epoch 83/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7928 - accuracy: 0.9899 - iou_score: 0.7502 - val_loss: 0.8249 - val_accuracy: 0.9803 - val_iou_score: 0.6214
# Epoch 84/100
# 33/33 [==============================] - 9s 286ms/step - loss: 0.7915 - accuracy: 0.9903 - iou_score: 0.7562 - val_loss: 0.8256 - val_accuracy: 0.9786 - val_iou_score: 0.6150
# Epoch 85/100
# 33/33 [==============================] - 9s 287ms/step - loss: 0.7907 - accuracy: 0.9901 - iou_score: 0.7603 - val_loss: 0.8289 - val_accuracy: 0.9786 - val_iou_score: 0.6087
# Epoch 86/100
# 33/33 [==============================] - 9s 285ms/step - loss: 0.7910 - accuracy: 0.9902 - iou_score: 0.7589 - val_loss: 0.8279 - val_accuracy: 0.9793 - val_iou_score: 0.6135
# Epoch 87/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7909 - accuracy: 0.9903 - iou_score: 0.7590 - val_loss: 0.8262 - val_accuracy: 0.9799 - val_iou_score: 0.6193
# Epoch 88/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7900 - accuracy: 0.9905 - iou_score: 0.7636 - val_loss: 0.8290 - val_accuracy: 0.9793 - val_iou_score: 0.6100
# Epoch 89/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.7901 - accuracy: 0.9904 - iou_score: 0.7637 - val_loss: 0.8304 - val_accuracy: 0.9814 - val_iou_score: 0.6083
# Epoch 90/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.7909 - accuracy: 0.9906 - iou_score: 0.7587 - val_loss: 0.8282 - val_accuracy: 0.9809 - val_iou_score: 0.6147
# Epoch 91/100
# 33/33 [==============================] - 9s 287ms/step - loss: 0.7906 - accuracy: 0.9902 - iou_score: 0.7603 - val_loss: 0.8315 - val_accuracy: 0.9806 - val_iou_score: 0.6049
# Epoch 92/100
# 33/33 [==============================] - 9s 280ms/step - loss: 0.7906 - accuracy: 0.9903 - iou_score: 0.7608 - val_loss: 0.8316 - val_accuracy: 0.9774 - val_iou_score: 0.6030
# Epoch 93/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7902 - accuracy: 0.9903 - iou_score: 0.7622 - val_loss: 0.8348 - val_accuracy: 0.9771 - val_iou_score: 0.5954
# Epoch 94/100
# 33/33 [==============================] - 9s 283ms/step - loss: 0.7915 - accuracy: 0.9899 - iou_score: 0.7558 - val_loss: 0.8412 - val_accuracy: 0.9692 - val_iou_score: 0.5736
# Epoch 95/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.7921 - accuracy: 0.9895 - iou_score: 0.7542 - val_loss: 0.8309 - val_accuracy: 0.9784 - val_iou_score: 0.6044
# Epoch 96/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7916 - accuracy: 0.9903 - iou_score: 0.7554 - val_loss: 0.8362 - val_accuracy: 0.9727 - val_iou_score: 0.5887
# Epoch 97/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.7914 - accuracy: 0.9900 - iou_score: 0.7570 - val_loss: 0.8313 - val_accuracy: 0.9777 - val_iou_score: 0.6038
# Epoch 98/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7904 - accuracy: 0.9902 - iou_score: 0.7608 - val_loss: 0.8274 - val_accuracy: 0.9800 - val_iou_score: 0.6164
# Epoch 99/100
# 33/33 [==============================] - 9s 284ms/step - loss: 0.7939 - accuracy: 0.9892 - iou_score: 0.7445 - val_loss: 0.8263 - val_accuracy: 0.9815 - val_iou_score: 0.6226
# Epoch 100/100
# 33/33 [==============================] - 9s 282ms/step - loss: 0.7921 - accuracy: 0.9893 - iou_score: 0.7534 - val_loss: 0.8201 - val_accuracy: 0.9821 - val_iou_score: 0.6369
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Load model for prediction or continue training

#For continuing training....
#The following gives an error: Unknown loss function: dice_loss_plus_1focal_loss
#This is because the model does not save loss function and metrics. So to compile and 
#continue training we need to provide these as custom_objects.

# my_model = load_model('brats_3d.hdf5')

#So let us add the loss as custom object... but the following throws another error...
#Unknown metric function: iou_score

# my_model = load_model('brats_3d.hdf5', 
#                       custom_objects={'dice_loss_plus_1focal_loss': total_loss})

#Now, let us add the iou_score function we used during our initial training
from keras.models import load_model
my_model = load_model('brats_3d.hdf5', 
                      custom_objects={'dice_loss_plus_1focal_loss': total_loss,
                                      'iou_score':sm.metrics.IOUScore(threshold=0.5)})

#Now all set to continue the training process. 
history2=my_model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=1,
          verbose=1,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          )
# Out:
# 33/33 [==============================] - 14s 286ms/step - loss: 0.7915 - accuracy: 0.9897 - iou_score: 0.7563 - val_loss: 0.8251 - val_accuracy: 0.9808 - val_iou_score: 0.6226

# %%
#For predictions you do not need to compile the model, so ...
my_model = load_model('brats_3d.hdf5', 
                      compile=False)


#Verify IoU on a batch of images from the test dataset
#Using built in keras function for IoU
#Only works on TF > 2.0
from keras.metrics import MeanIoU

batch_size=8 #Check IoU for a batch of images
test_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
test_image_batch, test_mask_batch = test_img_datagen.__next__()

test_mask_batch_argmax = np.argmax(test_mask_batch, axis=4)
test_pred_batch = my_model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=4)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 11s 11s/step
# Mean IoU = 0.66545415

# %%
img_num = 39
# img_num = 77
# img_num = 90

test_img = np.load("BraTS2020_TrainingData/input_data_128/val/images/image_"+str(img_num)+".npy")
test_mask = np.load("BraTS2020_TrainingData/input_data_128/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

# print(test_prediction_argmax.shape)
# print(test_mask_argmax.shape)
# print(np.unique(test_prediction_argmax))

#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 55
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step
